# %%
import pandas as pd

# %%
df = pd.read_csv("./train.csv")

# %%
df.head()
# Out:
#      AC    AF   AR    AS  AST   AY       AwayTeam      Date FTR    HC    HF  \
# 0   3.0  12.0  0.0  14.0  4.0  0.0      Stuttgart  07/08/09   H   6.0  12.0
# 1   1.0  10.0  0.0   7.0  0.0  1.0        FC Koln  08/08/09   H  16.0   8.0
# 2   3.0  20.0  0.0  15.0  3.0  2.0       Hannover  08/08/09   H   5.0  16.0
# 3  10.0  28.0  0.0   9.0  3.0  2.0  Bayern Munich  08/08/09   D   3.0  10.0
# 4   5.0  28.0  0.0  13.0  7.0  2.0     Leverkusen  08/08/09   D   3.0  22.0
#
#     HR    HS   HST  HTAG  HTHG   HY    HomeTeam      league
# 0  0.0  13.0   7.0   0.0   0.0  0.0   Wolfsburg  bundesliga
# 1  0.0  24.0  11.0   0.0   0.0  0.0    Dortmund  bundesliga
# 2  0.0  10.0   4.0   0.0   0.0  3.0      Hertha  bundesliga
# 3  0.0   9.0   1.0   1.0   1.0  0.0  Hoffenheim  bundesliga
# 4  0.0   8.0   4.0   2.0   1.0  1.0       Mainz  bundesliga

# %%
df.shape
# Out:
# (12789, 19)

# %%
df.columns
# Out:
# Index(['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'AwayTeam', 'Date', 'FTR', 'HC',
#        'HF', 'HR', 'HS', 'HST', 'HTAG', 'HTHG', 'HY', 'HomeTeam', 'league'],
#       dtype='object')

# %%
testdf = pd.read_csv("./test-3.csv")

# %%
testdf.shape
# Out:
# (1826, 20)

# %%
df.describe()
# Out:
#                  AC            AF            AR            AS           AST  \
# count  12780.000000  12778.000000  12780.000000  12780.000000  12780.000000
# mean       4.497966     14.411802      0.140063     11.234898      4.177465
# std        2.582074      4.668766      0.377728      4.526805      2.497475
# min        0.000000      1.000000      0.000000      0.000000      0.000000
# 25%        3.000000     11.000000      0.000000      8.000000      2.000000
# 50%        4.000000     14.000000      0.000000     11.000000      4.000000
# 75%        6.000000     17.000000      0.000000     14.000000      6.000000
# max       19.000000     34.000000      3.000000     39.000000     20.000000
#
#                  AY            HC            HF            HR            HS  \
# count  12780.000000  12780.000000  12778.000000  12780.000000  12780.000000
# mean       2.173552      5.791080     13.917123      0.101252     14.061033
# ...

# %%
nullcount  = df.isnull().sum()

# %%
count = 0
for x in nullcount.iteritems():
    count = count+ x[1]
print(count)
print(df.shape[0])
print(count/df.shape[0])
print((100)*count/df.shape[0])
# drop the 1.2% null data
# Out:
# 161
# 12789
# 0.012588943623426382
# 1.2588943623426383

# %% [markdown]
# # variable
# # AC: Away team corners

# %%
df["AC"].describe()
# Out:
# count    12780.000000
# mean         4.497966
# std          2.582074
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          6.000000
# max         19.000000
# Name: AC, dtype: float64

# %%
testdf["AC"].describe()
# Out:
# count    1826.000000
# mean        4.432092
# std         2.604115
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        16.000000
# Name: AC, dtype: float64

# %%
import matplotlib.pyplot as plt
df.AC.hist()
plt.plot()
# Out:
# []

# %%
testdf.AC.hist()
plt.plot()
# Out:
# []

# %%
import seaborn as sns

# %%
#Is train and test have the same distribution?
sns.distplot(df.AC.dropna(), kde=True, bins = 10);
sns.distplot(testdf.AC.dropna(), kde=True, bins = 10);
#YES

# %%
plt.boxplot(testdf.AC)
plt.plot()
# Out:
# []

# %%
df[df["AC"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %%
# drop na

# %%
# do an outlier analysis and remove outliers if any

# %% [markdown]
# # variable 'AF' Away Team Fouls Committed

# %%
df["AF"].describe()
# Out:
# count    12778.000000
# mean        14.411802
# std          4.668766
# min          1.000000
# 25%         11.000000
# 50%         14.000000
# 75%         17.000000
# max         34.000000
# Name: AF, dtype: float64

# %%
testdf["AF"].describe()
# Out:
# count    1826.000000
# mean       12.819277
# std         4.209992
# min         0.000000
# 25%        10.000000
# 50%        12.000000
# 75%        16.000000
# max        29.000000
# Name: AF, dtype: float64

# %%
df.AF.hist()
plt.plot()
# Out:
# []

# %%
testdf.AF.hist()
plt.plot()
# Out:
# []

# %%
#Is train and test have the same distribution?
sns.distplot(df.AF.dropna(), kde=True, bins = 10);
sns.distplot(testdf.AF.dropna(), kde=True, bins = 10);

# %%
plt.boxplot(testdf.AF)
plt.plot()
# Out:
# []

# %%
df[df["AF"].isnull() == True]
# Out:
#         AC  AF   AR   AS  AST   AY   AwayTeam      Date  FTR   HC  HF   HR  \
# 5620   5.0 NaN  0.0  6.0  3.0  3.0  Marseille  18/09/11    H  3.0 NaN  0.0
# 5733   1.0 NaN  0.0  9.0  3.0  5.0      Nancy  17/12/11    A  8.0 NaN  0.0
# 7082   NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
# 7408   NaN NaN  NaN  NaN  NaN  NaN       Lyon  16/04/17    A  NaN NaN  NaN
# 9363   NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
# 11298  NaN NaN  NaN  NaN  NaN  NaN       Roma  23/09/12    A  NaN NaN  NaN
# 11644  NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
# 11645  NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
# 11646  NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
# 12027  NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
# 12408  NaN NaN  NaN  NaN  NaN  NaN        NaN       NaN  NaN  NaN NaN  NaN
#
#          HS  HST  HTAG  HTHG   HY  HomeTeam          league
# ...

# %% [markdown]
# # variable 'AR'
# # Away Team Red Cards

# %%
df["AR"].describe()
# Out:
# count    12780.000000
# mean         0.140063
# std          0.377728
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          3.000000
# Name: AR, dtype: float64

# %%
df["AR"].unique()
# Out:
# array([ 0.,  1.,  2.,  3., nan])

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
ar_count = df['AR'].value_counts()
sns.set(style="darkgrid")
sns.barplot(ar_count.index, ar_count.values, alpha=0.9)
plt.title('Frequency Distribution of ar_count')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('AR', fontsize=12)
plt.show()

# %%
testdf.AR.hist()
plt.plot()
# Out:
# []

# %%
df[df["AR"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %% [markdown]
# # variable  'AS'
# # Away Team Shots

# %%
df["AS"].describe()
# Out:
# count    12780.000000
# mean        11.234898
# std          4.526805
# min          0.000000
# 25%          8.000000
# 50%         11.000000
# 75%         14.000000
# max         39.000000
# Name: AS, dtype: float64

# %%
testdf["AS"].describe()
# Out:
# count    1826.000000
# mean       11.032311
# std         4.575162
# min         0.000000
# 25%         8.000000
# 50%        11.000000
# 75%        14.000000
# max        30.000000
# Name: AS, dtype: float64

# %%
df.AS.hist()
plt.plot()
# Out:
# []

# %%
testdf.AS.hist()
plt.plot()
# Out:
# []

# %%
#Is train and test have the same distribution?
sns.distplot(df.AS.dropna(), kde=True, bins = 10);
sns.distplot(testdf.AS.dropna(), kde=True, bins = 10);

# %%
plt.boxplot(testdf.AS)
plt.plot()
# Out:
# []

# %%
df[df["AS"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %% [markdown]
# # variable  'AST'
# # Away Team Shots on Target

# %%
df["AST"].describe()
# Out:
# count    12780.000000
# mean         4.177465
# std          2.497475
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          6.000000
# max         20.000000
# Name: AST, dtype: float64

# %%
testdf["AST"].describe()
# Out:
# count    1826.000000
# mean        3.859255
# std         2.369998
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max        14.000000
# Name: AST, dtype: float64

# %%
df.AST.hist()
plt.plot()
# Out:
# []

# %%
testdf.AST.hist()
plt.plot()
# Out:
# []

# %%
#Is train and test have the same distribution?
sns.distplot(df.AST.dropna(), kde=True, bins = 10);
sns.distplot(testdf.AST.dropna(), kde=True, bins = 10);

# %%
plt.boxplot(testdf.AST)
plt.plot()
# Out:
# []

# %%
df[df["AST"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %% [markdown]
# # variable  'AY'
# # Away Team Yellow Cards

# %%
df["AC"].describe()
# Out:
# count    1826.000000
# mean        4.432092
# std         2.604115
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        16.000000
# Name: AC, dtype: float64

# %%
testdf["AC"].describe()
# Out:
# count    1826.000000
# mean        4.432092
# std         2.604115
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        16.000000
# Name: AC, dtype: float64

# %%
df.AC.hist()
plt.plot()
# Out:
# []

# %%
testdf.AC.hist()
plt.plot()
# Out:
# []

# %%
#Is train and test have the same distribution?
sns.distplot(df.AC.dropna(), kde=True, bins = 10);
sns.distplot(testdf.AC.dropna(), kde=True, bins = 10);

# %%
plt.boxplot(testdf.AC)
plt.plot()
# Out:
# []

# %%
df[df["AC"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %% [markdown]
# # variable 'AwayTeam'

# %%
df["AwayTeam"].describe()
# Out:
# count     12782
# unique      159
# top       Milan
# freq        133
# Name: AwayTeam, dtype: object

# %%
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

is_string_dtype(df['AwayTeam'])
# Out:
# True

# %%
df["AwayTeam"].unique()
# Out:
# array(['Stuttgart', 'FC Koln', 'Hannover', 'Bayern Munich', 'Leverkusen',
#        'Schalke 04', 'Ein Frankfurt', "M'gladbach", 'Hamburg',
#        'Werder Bremen', 'Nurnberg', 'Wolfsburg', 'Dortmund', 'Mainz',
#        'Hoffenheim', 'Freiburg', 'Hertha', 'Bochum', 'Kaiserslautern',
#        'St Pauli', 'Augsburg', 'Fortuna Dusseldorf', 'Greuther Furth',
#        'Paderborn', 'Ingolstadt', 'Darmstadt', 'RB Leipzig', 'La Coruna',
#        'Tenerife', 'Valladolid', 'Espanol', 'Ath Madrid', 'Xerez',
#        'Villarreal', 'Getafe', 'Sevilla', 'Sp Gijon', 'Santander',
#        'Real Madrid', 'Barcelona', 'Zaragoza', 'Malaga', 'Almeria',
#        'Osasuna', 'Valencia', 'Mallorca', 'Ath Bilbao', 'Hercules',
#        'Levante', 'Sociedad', 'Betis', 'Vallecano', 'Granada', 'Celta',
#        'Elche', 'Cordoba', 'Eibar', 'Las Palmas', 'Alaves', 'Leganes',
#        'Sochaux', 'Marseille', 'Lyon', 'Toulouse', 'Paris SG', 'Boulogne',
# ...

# %%
testdf["AwayTeam"].describe()
# Out:
# count           1826
# unique            98
# top       St Etienne
# freq              19
# Name: AwayTeam, dtype: object

# %%
testdf["AwayTeam"].unique()
# Out:
# array(['Leverkusen', 'Augsburg', 'Stuttgart', 'Werder Bremen', 'Hannover',
#        'RB Leipzig', 'Dortmund', 'Ein Frankfurt', 'FC Koln', 'Hamburg',
#        "M'gladbach", 'Hertha', 'Wolfsburg', 'Hoffenheim', 'Mainz',
#        'Bayern Munich', 'Schalke 04', 'Freiburg', 'Alaves', 'Las Palmas',
#        'Sociedad', 'Ath Madrid', 'Espanol', 'Getafe', 'Betis',
#        'Real Madrid', 'Villarreal', 'Eibar', 'Celta', 'Barcelona',
#        'Malaga', 'La Coruna', 'Ath Bilbao', 'Leganes', 'Sevilla',
#        'Valencia', 'Levante', 'Girona', 'Toulouse', 'Strasbourg',
#        'Guingamp', 'Caen', 'Amiens', 'Nice', 'Rennes', 'Bordeaux',
#        'Nantes', 'Dijon', 'Troyes', 'Lyon', 'Angers', 'Metz',
#        'St Etienne', 'Marseille', 'Montpellier', 'Monaco', 'Paris SG',
#        'Lille', 'Leicester', 'Man City', 'Burnley', 'Huddersfield',
#        'Stoke', 'Swansea', 'Liverpool', 'Bournemouth', 'West Ham',
#        'Tottenham', 'Watford', 'West Brom', 'Brighton', 'Crystal Palace',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 50))
awayteamcounts = df['AwayTeam'].value_counts()
sns.set(style="darkgrid")
sns.barplot(awayteamcounts.values, awayteamcounts.index, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('awayteam', fontsize=12)
plt.xlabel('Number of occurences', fontsize=12)
plt.show()

# %%
df[df["AwayTeam"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam Date  FTR  HC  HF  HR  HS  HST  HTAG  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
#
#        HTHG  HY HomeTeam          league
# 7082    NaN NaN      NaN         ligue-1
# 9363    NaN NaN      NaN  premier-league
# 11644   NaN NaN      NaN         serie-a
# 11645   NaN NaN      NaN         serie-a
# 11646   NaN NaN      NaN         serie-a
# 12027   NaN NaN      NaN         serie-a
# 12408   NaN NaN      NaN         serie-a

# %% [markdown]
# # variable  'Date'
# # On which day the match was played

# %%
is_string_dtype(df['Date'])
# Out:
# True

# %%
df["Date"].describe()
# Out:
# count        12782
# unique        1227
# top       13/05/12
# freq            38
# Name: Date, dtype: object

# %%
len(df["Date"].unique())
# Out:
# 1228

# %%
len(testdf["Date"].unique())
# Out:
# 178

# %%
df[df["Date"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam Date  FTR  HC  HF  HR  HS  HST  HTAG  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN  NaN  NaN NaN NaN NaN NaN  NaN   NaN
#
#        HTHG  HY HomeTeam          league
# 7082    NaN NaN      NaN         ligue-1
# 9363    NaN NaN      NaN  premier-league
# 11644   NaN NaN      NaN         serie-a
# 11645   NaN NaN      NaN         serie-a
# 11646   NaN NaN      NaN         serie-a
# 12027   NaN NaN      NaN         serie-a
# 12408   NaN NaN      NaN         serie-a

# %% [markdown]
# # variable 'FTR'
# # Full-Time Result (H=Home Win, D=Draw, A=Away Win)

# %%
df["FTR"].describe()
# Out:
# count     12782
# unique        3
# top           H
# freq       5931
# Name: FTR, dtype: object

# %%
df["FTR"].unique()
# Out:
# array(['H', 'D', 'A', nan], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
ftrcounts = df['FTR'].value_counts()
sns.set(style="darkgrid")
sns.barplot( ftrcounts.index,ftrcounts.values, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('Number of occurences', fontsize=12)
plt.xlabel('FTR ', fontsize=12)
plt.show()

# %% [markdown]
# # variable , 'HC'
# # Home Team Corners

# %%
df["HC"].describe()
# Out:
# count    12780.000000
# mean         5.791080
# std          3.012718
# min          0.000000
# 25%          4.000000
# 50%          5.000000
# 75%          8.000000
# max         21.000000
# Name: HC, dtype: float64

# %%
df["HC"].unique()
# Out:
# array([ 6., 16.,  5.,  3.,  9., 11., 12.,  4., 10.,  8.,  7.,  2.,  1.,
#        15., 13., 14.,  0., 17., 18., 20., 19., nan, 21.])

# %%
len(df["HC"].unique())
# Out:
# 23

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
hccounts = df['HC'].value_counts()
sns.set(style="darkgrid")
sns.barplot( hccounts.index,hccounts.values, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('Number of occurences', fontsize=12)
plt.xlabel('HC ', fontsize=12)
plt.show()

# %% [markdown]
# # variable 'HF'
# # Home Team Fouls Committed

# %%
df["HF"].describe()
# Out:
# count    12778.000000
# mean        13.917123
# std          4.572456
# min          1.000000
# 25%         11.000000
# 50%         14.000000
# 75%         17.000000
# max         38.000000
# Name: HF, dtype: float64

# %%
df["HF"].unique()
# Out:
# array([12.,  8., 16., 10., 22., 14., 18., 13., 17., 20.,  9., 24., 21.,
#        11., 15., 19., 25., 23.,  5., 29., 30., 28., 26., 32.,  6.,  7.,
#        27.,  4.,  3., 31.,  2., 33.,  1., nan, 34., 35., 38.])

# %%
len(df["HF"].unique())
# Out:
# 37

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
hfcounts = df['HF'].value_counts()
sns.set(style="darkgrid")
sns.barplot( hfcounts.index,hfcounts.values, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('Number of occurences', fontsize=12)
plt.xlabel('HF ', fontsize=12)
plt.show()

# %% [markdown]
# # variable  'HR'
# # Home Team Red Cards

# %%
df["HR"].describe()
# Out:
# count    12780.000000
# mean         0.101252
# std          0.320539
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          3.000000
# Name: HR, dtype: float64

# %%
df["HR"].unique()
# Out:
# array([ 0.,  1.,  2.,  3., nan])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
hrcounts = df['HR'].value_counts()
sns.set(style="darkgrid")
sns.barplot( hrcounts.index,hrcounts.values, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('Number of occurences', fontsize=12)
plt.xlabel('HR ', fontsize=12)
plt.show()

# %% [markdown]
# # variable  'HS'
# # Home Team Shots

# %%
df["HS"].describe()
# Out:
# count    12780.000000
# mean        14.061033
# std          5.170604
# min          1.000000
# 25%         10.000000
# 50%         14.000000
# 75%         17.000000
# max         43.000000
# Name: HS, dtype: float64

# %%
df["HS"].unique()
# Out:
# array([13., 24., 10.,  9.,  8., 14., 22., 28., 17., 12., 18., 20., 15.,
#         7., 16., 32., 21., 23., 11., 19.,  4.,  5.,  6.,  3., 27., 25.,
#        26., 30., 29., 31.,  2., 33.,  1., 36., 37., 34., 35., nan, 43.,
#        38.])

# %%
len(df["HS"].unique())
# Out:
# 40

# %%
df.HS.hist()
plt.plot()
# Out:
# []

# %% [markdown]
# # variable  'HST'
# # Home Team Shots on Target

# %%
df["HST"].describe()
# Out:
# count    12780.000000
# mean         5.268545
# std          2.872875
# min          0.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         24.000000
# Name: HST, dtype: float64

# %%
df["HST"].unique()
# Out:
# array([ 7., 11.,  4.,  1.,  3., 10.,  8.,  6.,  9.,  5.,  0.,  2., 13.,
#        12., 14., 15., 16., 18., nan, 17., 19., 21., 20., 24.])

# %%
len(df["HST"].unique())
# Out:
# 24

# %%
df.HST.hist()
plt.plot()
# Out:
# []

# %%
df[df["HST"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %% [markdown]
# # variable  'HTAG'
# # Half Time Away Team Goals

# %%
df["HTAG"].describe()
# Out:
# count    12779.000000
# mean         0.494796
# std          0.713903
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: HTAG, dtype: float64

# %%
df["HTAG"].unique()
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  5., nan])

# %%
df.HTAG.hist()
plt.plot()
testdf.HTAG.hist()
plt.plot()
# Out:
# []

# %%
df[df["AC"].isnull() == True]
# Out:
#        AC  AF  AR  AS  AST  AY AwayTeam      Date  FTR  HC  HF  HR  HS  HST  \
# 7082  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 7408  NaN NaN NaN NaN  NaN NaN     Lyon  16/04/17    A NaN NaN NaN NaN  NaN
# 9363  NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11298 NaN NaN NaN NaN  NaN NaN     Roma  23/09/12    A NaN NaN NaN NaN  NaN
# 11644 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11645 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 11646 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12027 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
# 12408 NaN NaN NaN NaN  NaN NaN      NaN       NaN  NaN NaN NaN NaN NaN  NaN
#
#        HTAG  HTHG  HY  HomeTeam          league
# 7082    NaN   NaN NaN       NaN         ligue-1
# 7408    NaN   NaN NaN    Bastia         ligue-1
# 9363    NaN   NaN NaN       NaN  premier-league
# ...

# %% [markdown]
# # variable  'HTHG'
# # Half Time Home Team Goals

# %%
df["HTHG"].describe()
# Out:
# count    12779.000000
# mean         0.691134
# std          0.833159
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: HTHG, dtype: float64

# %%
df["HTHG"].unique()
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  5., nan])

# %%
df.HTHG.hist()
plt.plot()
testdf.HTHG.hist()
plt.plot()
# Out:
# []

# %%
df[df["HTHG"].isnull() == True]
# Out:
#         AC    AF   AR    AS  AST   AY AwayTeam      Date  FTR   HC    HF   HR  \
# 7082   NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 7408   NaN   NaN  NaN   NaN  NaN  NaN     Lyon  16/04/17    A  NaN   NaN  NaN
# 9363   NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 11298  NaN   NaN  NaN   NaN  NaN  NaN     Roma  23/09/12    A  NaN   NaN  NaN
# 11644  NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 11645  NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 11646  NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 12027  NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 12408  NaN   NaN  NaN   NaN  NaN  NaN      NaN       NaN  NaN  NaN   NaN  NaN
# 12426  7.0  21.0  0.0  15.0  5.0  2.0  Pescara  28/08/16    A  2.0  12.0  0.0
#
#          HS  HST  HTAG  HTHG   HY  HomeTeam          league
# ...

# %% [markdown]
# # variable  'HY'
# # Home Team Yellow Cards

# %%
df["HY"].describe()
# Out:
# count    1826.000000
# mean        1.821468
# std         1.382434
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000
# Name: HY, dtype: float64

# %%
testdf["HY"].describe()
# Out:
# count    1826.000000
# mean        1.821468
# std         1.382434
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         8.000000
# Name: HY, dtype: float64

# %%
df["HY"].unique()
# Out:
# array([ 0.,  3.,  1.,  2.,  4.,  6.,  5.,  7.,  8., nan])

# %%
len(df["HY"].unique())
# Out:
# 10

# %%
df.HY.hist()
plt.plot()
# Out:
# []

# %% [markdown]
# # variable 'HomeTeam'

# %%
df["HomeTeam"].describe()
# Out:
# count     12782
# unique      159
# top       Milan
# freq        133
# Name: HomeTeam, dtype: object

# %%
df["HomeTeam"].unique()
# Out:
# array(['Wolfsburg', 'Dortmund', 'Hertha', 'Hoffenheim', 'Mainz',
#        'Nurnberg', 'Werder Bremen', 'Bochum', 'Freiburg', 'Bayern Munich',
#        'Ein Frankfurt', 'FC Koln', 'Hamburg', 'Hannover', 'Leverkusen',
#        'Stuttgart', "M'gladbach", 'Schalke 04', 'Kaiserslautern',
#        'St Pauli', 'Augsburg', 'Greuther Furth', 'Fortuna Dusseldorf',
#        'Paderborn', 'Darmstadt', 'Ingolstadt', 'RB Leipzig',
#        'Real Madrid', 'Zaragoza', 'Almeria', 'Ath Bilbao', 'Malaga',
#        'Mallorca', 'Osasuna', 'Santander', 'Valencia', 'Barcelona',
#        'Ath Madrid', 'Espanol', 'Getafe', 'Sevilla', 'La Coruna',
#        'Sp Gijon', 'Tenerife', 'Valladolid', 'Villarreal', 'Xerez',
#        'Hercules', 'Levante', 'Sociedad', 'Granada', 'Betis', 'Vallecano',
#        'Celta', 'Eibar', 'Cordoba', 'Elche', 'Las Palmas', 'Leganes',
#        'Alaves', 'Auxerre', 'Grenoble', 'Le Mans', 'Monaco',
#        'Montpellier', 'Rennes', 'St Etienne', 'Valenciennes', 'Bordeaux',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 50))
hometeamcounts = df['HomeTeam'].value_counts()
sns.set(style="darkgrid")
sns.barplot(hometeamcounts.values, hometeamcounts.index, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('hometeam', fontsize=12)
plt.xlabel('Number of occurences', fontsize=12)
plt.show()

# %% [markdown]
# # variable  'league'
# # Under which league the match was played

# %%
df["league"].describe()
# Out:
# count       12789
# unique          5
# top       serie-a
# freq         2665
# Name: league, dtype: object

# %%
df["league"].unique()
# Out:
# array(['bundesliga', 'la-liga', 'ligue-1', 'premier-league', 'serie-a'],
#       dtype=object)

# %%
len(df["league"].unique())
# Out:
# 5

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
lcounts = df['league'].value_counts()
sns.set(style="darkgrid")
sns.barplot(lcounts.values, lcounts.index, alpha=0.9)
plt.title('Frequency Distribution')
plt.ylabel('lcounts', fontsize=12)
plt.xlabel('Number of occurences', fontsize=12)
plt.show()
